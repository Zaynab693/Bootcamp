# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
np.random.seed(42)

months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
          'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

cities = [f'City {i}' for i in range(1, 11)]


temperatures = np.random.uniform(low=-5, high=35, size=(10, 12))


df = pd.DataFrame(temperatures, index=cities, columns=months)

df
# Out:
#                Jan        Feb        Mar        Apr        May        Jun  \
# City 1    9.981605  33.028572  24.279758  18.946339   1.240746   1.239781
# City 2   28.297706   3.493564   2.272999   2.336180   7.169690  15.990257
# City 3   13.242799  26.407038   2.986951  15.569378  18.696583  -3.141983
# City 4    7.184551  -1.093115  22.369321  12.606100  -0.118471  14.807076
# City 5   16.868411   2.394178  33.783385  26.005313  32.579958  30.793094
# City 6   10.547092   5.853961  28.149500   9.270133   6.237380  16.707843
# City 7   -4.779115  27.618457  23.274294  24.160287  25.850814  -2.038214
# City 8    7.439293   8.007333  24.184247  20.502299  30.488510  13.888597
# City 9   15.909313  12.101641  -3.983235  -0.684343  -3.742833  20.456416
# City 10   4.151927  -1.920804   6.590058   1.448851  32.187906  27.324815
#
#                Jul        Aug        Sep        Oct        Nov        Dec
# City 1   -2.676656  29.647046  19.044600  23.322903  -4.176620  33.796394
# ...

# %%
annual_avg = df.mean(axis=1)
annual_avg
# Out:
# City 1     15.639539
# City 2      9.573458
# City 3     15.533515
# City 4     11.135589
# City 5     16.618052
# City 6     13.815557
# City 7     13.191186
# City 8     17.608070
# City 9     11.323811
# City 10    16.405255
# dtype: float64

# %%
hottest_city = annual_avg.idxmax()
coldest_city = annual_avg.idxmin()

print("Hottest city:", hottest_city)
print("Coldest city:", coldest_city)
# Out:
# Hottest city: City 8
# Coldest city: City 2

# %%
plt.figure(figsize=(14, 8))

for city in df.index:
    plt.plot(df.columns, df.loc[city], label=city)

plt.title("Monthly Temperature Trends for Each City")
plt.xlabel("Month")
plt.ylabel("Temperature (°C)")
plt.legend(loc="upper left", bbox_to_anchor=(1,1))
plt.grid(True)
plt.show()

# %%
''' Summary Report

- The dataset represents synthetic average monthly temperatures for 10 cities.
- The hottest city on average over the year is **City X**.
- The coldest city on average over the year is **City Y**.
- Temperature trends show noticeable seasonal variations across all cities.
- Some cities experience extreme temperature fluctuations, while others remain relatively stable.
'''
# Out:
# ' Summary Report\n\n- The dataset represents synthetic average monthly temperatures for 10 cities.\n- The hottest city on average over the year is **City X**.\n- The coldest city on average over the year is **City Y**.\n- Temperature trends show noticeable seasonal variations across all cities.\n- Some cities experience extreme temperature fluctuations, while others remain relatively stable.\n'
