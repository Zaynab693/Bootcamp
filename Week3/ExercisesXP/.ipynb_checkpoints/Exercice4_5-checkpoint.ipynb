# %%
import pandas as pd

# %%
iris_df = pd.read_csv(r"C:\Users\asus\Desktop\GenAI\Week3\ExercicesXP\Iris_Dataset\Iris.csv")

# %%
iris_df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris_df = pd.read_csv(r"C:\Users\asus\Desktop\GenAI\Week3\ExercicesXP\Iris_Dataset\Iris.csv")
quantitative_columns=iris_df.select_dtypes(include=['int64', 'float64']).columns
list(quantitative_columns)
# Out:
# ['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']

# %%
qualitative_columns=iris_df.select_dtypes(include=['object']).columns
list(qualitative_columns)
# Out:
# ['Species']
